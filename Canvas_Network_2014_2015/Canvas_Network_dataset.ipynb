# %%
import os 
import pandas as pd

# %%
path = ("D:\Downloads\py\Master Courses\TFM\Data\Datasets\Canvas_Network_2014_2015")
os.chdir(path)

# %%
df = pd.read_csv("CNPC_1401-1509_DI_v1_1_2016-03-01.tab", sep = '\t', header = None, engine = 'python')
df.head()
# Out:
#           0                                 1          2   3   4   5      6   \
# 0  832945142          Mathematics & Statistics  832433672   1   0   0  0.000
# 1  832960754                         Education  832367550   1   1   0  0.358
# 2  832945598  Professions and Applied Sciences  832626198   1   1   0  0.000
# 3  832945596  Professions and Applied Sciences  832633777   1   0   0  0.000
# 4  832945508                        Humanities  832676450   1   0   0    NaN
#
#    7   8   9   ...  16       17       18       19       20    21   22     23  \
# 0   0 NaN   0  ...  {}      NaN  2014 Q1  2014 Q2      NaN   NaN  NaN    NaN
# 1   1 NaN   1  ...  {}  2015 Q2  2015 Q2  2015 Q2  2015 Q2  45.0  3.0  100.0
# 2   0 NaN   0  ...  {}  2015 Q1  2014 Q4  2015 Q2  2015 Q1  35.0  1.0    NaN
# 3   0 NaN   0  ...  {}      NaN  2014 Q4  2015 Q2      NaN   NaN  NaN    NaN
# 4   0 NaN   0  ...  {}      NaN  2014 Q3  2014 Q4      NaN   NaN  NaN    NaN
#
#     24   25
# 0  NaN   48
# 1  7.0   42
# ...

# %%
df.columns = ['course_id_DI', 'course_name', 'user_id_DI', 'registered', 'viewed', 'explored', 'completed_%', 'course_reqs', 'grade_reqs', 'primary_reason', 'final_cc_cname_DI', 'primary_reasons', 'learner_type', 'expec_hours_week', 'LoE', 'age_DI', 'gender', 'start_time_DI', 'course_start', 'course_end', 'last_event_DI', 'nevents', 'ndays_act', 'nchapters', 'nforum_posts', 'course_length' ]

# %%
df.head()
# Out:
#    course_id_DI                       course_name  user_id_DI  registered  \
# 0     832945142          Mathematics & Statistics   832433672           1
# 1     832960754                         Education   832367550           1
# 2     832945598  Professions and Applied Sciences   832626198           1
# 3     832945596  Professions and Applied Sciences   832633777           1
# 4     832945508                        Humanities   832676450           1
#
#    viewed  explored  completed_%  course_reqs  grade_reqs  primary_reason  \
# 0       0         0        0.000            0         NaN               0
# 1       1         0        0.358            1         NaN               1
# 2       1         0        0.000            0         NaN               0
# 3       0         0        0.000            0         NaN               0
# 4       0         0          NaN            0         NaN               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325199 entries, 0 to 325198
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   course_id_DI       325199 non-null  int64
#  1   course_name        325199 non-null  object
#  2   user_id_DI         325199 non-null  int64
#  3   registered         325199 non-null  int64
#  4   viewed             325199 non-null  int64
#  5   explored           325199 non-null  int64
#  6   completed_%        82002 non-null   float64
#  7   course_reqs        325199 non-null  int64
#  8   grade_reqs         26661 non-null   float64
#  9   primary_reason     325199 non-null  int64
#  10  final_cc_cname_DI  325199 non-null  object
#  11  primary_reasons    38371 non-null   object
#  12  learner_type       38371 non-null   object
#  13  expec_hours_week   38371 non-null   object
#  14  LoE                38371 non-null   object
# ...

# %%
df.describe()
# Out:
#        course_id_DI    user_id_DI  registered         viewed       explored  \
# count  3.251990e+05  3.251990e+05    325199.0  325199.000000  325199.000000
# mean   8.329516e+08  8.325481e+08         1.0       0.244389       0.029923
# std    7.501043e+03  4.117930e+05         0.0       0.429725       0.170376
# min    8.329451e+08  8.323000e+08         1.0       0.000000       0.000000
# 25%    8.329453e+08  8.323918e+08         1.0       0.000000       0.000000
# 50%    8.329456e+08  8.324859e+08         1.0       0.000000       0.000000
# 75%    8.329607e+08  8.326639e+08         1.0       0.000000       0.000000
# max    8.329610e+08  8.899539e+08         1.0       1.000000       1.000000
#
#         completed_%    course_reqs    grade_reqs  primary_reason  \
# count  82002.000000  325199.000000  26661.000000   325199.000000
# mean       0.304836       0.126329      0.263367        0.108063
# std        0.363387       0.332220      0.277268        0.310461
# ...
